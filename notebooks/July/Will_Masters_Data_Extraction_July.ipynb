# %%
#Import Stuff
import pyart
import scipy
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import pandas as pd
from datetime import datetime
import os
import seaborn as sns
import xarray as xr

# %%
### Radar Location
radar_Lat=51.144682
radar_Long=-1.4393
radar_Alt=85.8


### Trap Locations
Porton_Down_Lat=51.1443825
Porton_Down_Long=-1.6826019
Porton_Down_Alt=110
radar_to_Porton_Down_Bearing=269.9822
radar_to_Porton_Down_Distance=16.97*1000

Bentley_Wood_Lat=51.0903015
Bentley_Wood_Long=-1.6401474
Bentley_Wood_Alt=130
radar_to_Bentley_Wood_Bearing=246.7464
radar_to_Bentley_Wood_Distance=15.27*1000

# %%
data_dir='/Volumes/BioTxfer/calib_v2_2_sur'

# %%
day_dirs=glob(data_dir+'/201707*')
len(day_dirs)
day_dirs.sort()
day_dirs
# Out:
# ['/Volumes/BioTxfer/calib_v2_2_sur/20170704',
#  '/Volumes/BioTxfer/calib_v2_2_sur/20170705',
#  '/Volumes/BioTxfer/calib_v2_2_sur/20170706',
#  '/Volumes/BioTxfer/calib_v2_2_sur/20170707',
#  '/Volumes/BioTxfer/calib_v2_2_sur/20170708',
#  '/Volumes/BioTxfer/calib_v2_2_sur/20170709',
#  '/Volumes/BioTxfer/calib_v2_2_sur/20170710',
#  '/Volumes/BioTxfer/calib_v2_2_sur/20170711',
#  '/Volumes/BioTxfer/calib_v2_2_sur/20170712']

# %%
def files_in_day(day_dir):
    files_in_day=glob(day_dir+'/*201707*.nc')
    files_in_day.sort()
    return files_in_day

# %%
def all_files(data_dir,findstr):
    print(data_dir+'/*/'+findstr+'*')
    files= glob(data_dir+'/**/*'+findstr+'*.nc', recursive=True)
    files.sort()
    return files

# %%
files=files_in_day(day_dirs[0])

# %%
radar=pyart.io.read(files[0])

# %%
radar.fields.keys()
# Out:
# dict_keys(['RhoHV', 'SNRv', 'ZDR', 'dBZ', 'uKDPu', 'DOP', 'SQIvu', 'PhiDP', 'dBuZ', 'CCOR', 'Vvu', 'Wvu', 'Wv', 'Wu', 'uPhiDP', 'KDP', 'dBZv', 'forecast_temp_qc', 'dBuZv', 'SNRvu', 'RhoHVu', 'CCORv', 'SNRu', 'ZDRu', 'W', 'V', 'u_wind_component', 'temperature', 'SQIv', 'SQIu', 'uPhiDPu', 'rh', 'SQI', 'v_wind_component', 'SNR', 'Vu', 'Vv', 'DOPu', 'uKDP'])

# %%
radar=pyart.io.read(files[0])

def find_nearest_7x3(radar,a0,r0, base_alt):
    idx_a = np.squeeze(np.where((radar.azimuth['data'][:]>a0-0.5) &  (radar.azimuth['data'][:]<a0+0.5))[0])
    idx_a_7x3=np.squeeze([idx_a-1,idx_a,idx_a+1])
    
    idx_r_7x3=[]
    for i in np.arange(0,len(idx_a_7x3)):
        r=np.sqrt(radar.gate_x['data'][idx_a_7x3[i],:]**2+radar.gate_y['data'][idx_a_7x3[i],:]**2)
        idx_r = np.where((r>r0-75) & (r<r0+75))[1]
        if i==0:
            idx_r_7x3=[[idx_r-3],[idx_r-2],[idx_r-1],[idx_r],[idx_r+1],[idx_r+2],[idx_r+3]]
        else:
            idx_r_7x3=np.append(idx_r_7x3, [[idx_r-3],[idx_r-2],[idx_r-1],[idx_r],[idx_r+1],[idx_r+2],[idx_r+3]],axis=1)
    
    Azis=radar.azimuth['data'][idx_a_7x3]
    Ranges=radar.range['data'][idx_r_7x3]
    X=radar.gate_x['data'][idx_a_7x3, idx_r_7x3]
    Y=radar.gate_y['data'][idx_a_7x3, idx_r_7x3]
    Z=radar.gate_z['data'][idx_a_7x3, idx_r_7x3]+radar.altitude['data'].data[0]-base_alt
    #test=np.nanmean(np.nanmean(radar.fields['dBZ']['data'][idx_a_7x3, idx_r_7x3],0),0)
    return idx_a_7x3, idx_r_7x3, Azis, Ranges,  X, Y, Z,# test


#, idx_r_7x3, radar.gate_y['data'][idx_a_7x3,idx_r_7x3], radar.gate_z['data'][idx_a_7x3,idx_r_7x3],


Porton_Down_Azis_Idx,Porton_Down_Ranges_Idx, Porton_Down_Azis, Porton_Down_Ranges, Porton_Down_X, Porton_Down_Y, Porton_Down_Z = find_nearest_7x3( radar,radar_to_Porton_Down_Bearing,radar_to_Porton_Down_Distance,Porton_Down_Alt)
Bentley_Wood_Azis_Idx,Bentley_Wood_Ranges_Idx, Bentley_Wood_Azis, Bentley_Wood_Ranges, Bentley_Wood_X, Bentley_Wood_Y, Bentley_Wood_Z = find_nearest_7x3(radar,radar_to_Bentley_Wood_Bearing, radar_to_Bentley_Wood_Distance,Bentley_Wood_Alt)


radar.fields['dBZ']['data'][Porton_Down_Azis_Idx,Porton_Down_Ranges_Idx]=-20

radar.fields['dBZ']['data'][Bentley_Wood_Azis_Idx,Bentley_Wood_Ranges_Idx]=-20

#Write Out Pixel Metrics
df_Porton_Down = pd.DataFrame(columns=['Scan_Elevation_degrees'])
df_Porton_Down['Scan_Elevation_degrees']=radar.fixed_angle['data']

df_Porton_Down['Max_Range']=np.nanmax(np.nanmax(Porton_Down_Ranges,0),0)
df_Porton_Down['Mean_Range']=np.nanmean(np.nanmean(Porton_Down_Ranges,0),0)
df_Porton_Down['Min_Range']=np.nanmin(np.nanmin(Porton_Down_Ranges,0),0)

df_Porton_Down['Max_Azimuth']=np.nanmax(np.nanmax(Porton_Down_Azis,0),0)
df_Porton_Down['Mean_Azimuth']=np.nanmean(np.nanmean(Porton_Down_Azis,0),0)
df_Porton_Down['Min_Azimuth']=np.nanmin(np.nanmin(Porton_Down_Azis,0),0)

df_Porton_Down['Max_X_Distance_from_Radar']=np.nanmax(np.nanmax(Porton_Down_X,0),0)
df_Porton_Down['Mean_X_Distance_from_Radar']=np.nanmean(np.nanmean(Porton_Down_X,0),0)
df_Porton_Down['Min_X_Distance_from_Radar']=np.nanmin(np.nanmin(Porton_Down_X,0),0)

df_Porton_Down['Max_Y_Distance_from_Radar']=np.nanmax(np.nanmax(Porton_Down_Y,0),0)
df_Porton_Down['Mean_Y_Distance_from_Radar']=np.nanmean(np.nanmean(Porton_Down_Y,0),0)
df_Porton_Down['Min_Y_Distance_from_Radar']=np.nanmin(np.nanmin(Porton_Down_Y,0),0)

df_Porton_Down['Max_Altitude_Above_Ground']=np.nanmax(np.nanmax(Porton_Down_Z,0),0)
df_Porton_Down['Mean_Altitude_Above_Ground']=np.nanmean(np.nanmean(Porton_Down_Z,0),0)
df_Porton_Down['Min_Altitude_Above_Ground']=np.nanmin(np.nanmin(Porton_Down_Z,0),0)


df_Bentley_Wood = pd.DataFrame(columns=['Scan_Elevation_degrees'])
df_Bentley_Wood['Scan_Elevation_degrees']=radar.fixed_angle['data']

df_Bentley_Wood['Max_Range']=np.nanmax(np.nanmax(Bentley_Wood_Ranges,0),0)
df_Bentley_Wood['Mean_Range']=np.nanmean(np.nanmean(Bentley_Wood_Ranges,0),0)
df_Bentley_Wood['Min_Range']=np.nanmin(np.nanmin(Bentley_Wood_Ranges,0),0)

df_Bentley_Wood['Max_Azimuth']=np.nanmax(np.nanmax(Bentley_Wood_Azis,0),0)
df_Bentley_Wood['Mean_Azimuth']=np.nanmean(np.nanmean(Bentley_Wood_Azis,0),0)
df_Bentley_Wood['Min_Azimuth']=np.nanmin(np.nanmin(Bentley_Wood_Azis,0),0)

df_Bentley_Wood['Max_X_Distance_from_Radar']=np.nanmax(np.nanmax(Bentley_Wood_X,0),0)
df_Bentley_Wood['Mean_X_Distance_from_Radar']=np.nanmean(np.nanmean(Bentley_Wood_X,0),0)
df_Bentley_Wood['Min_X_Distance_from_Radar']=np.nanmin(np.nanmin(Bentley_Wood_X,0),0)

df_Bentley_Wood['Max_Y_Distance_from_Radar']=np.nanmax(np.nanmax(Bentley_Wood_Y,0),0)
df_Bentley_Wood['Mean_Y_Distance_from_Radar']=np.nanmean(np.nanmean(Bentley_Wood_Y,0),0)
df_Bentley_Wood['Min_Y_Distance_from_Radar']=np.nanmin(np.nanmin(Bentley_Wood_Y,0),0)

df_Bentley_Wood['Max_Altitude_Above_Ground']=np.nanmax(np.nanmax(Bentley_Wood_Z,0),0)
df_Bentley_Wood['Mean_Altitude_Above_Ground']=np.nanmean(np.nanmean(Bentley_Wood_Z,0),0)
df_Bentley_Wood['Min_Altitude_Above_Ground']=np.nanmin(np.nanmin(Bentley_Wood_Z,0),0)



try:
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Porton_Down_Closest_7x3_Metrics.xlsx')
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Bentley_Wood_Closest_7x3_Metrics.xlsx')

except:
    print('No File To Delete')
    
df_Porton_DownT=df_Porton_Down.T  
df_Bentley_WoodT=df_Bentley_Wood.T

df_Porton_DownT.to_excel("Porton_Down_Closest_7x3_Metrics.xlsx", sheet_name='Porton_Down_7x3_Metrics')
df_Bentley_WoodT.to_excel("Bentley_Wood_Closest_7x3_Metrics.xlsx", sheet_name='Bentley_Wood_7x3_Metrics')
# Out:
# No File To Delete

# %%
def find_nearest_4x2(radar,a0,r0, base_alt):
    idx_a = np.squeeze(np.where((radar.azimuth['data'][:]>a0-0.5) &  (radar.azimuth['data'][:]<a0+0.5))[0])
    idx_a_4x2=np.squeeze([idx_a,idx_a+1])
    
    idx_r_4x2=[]
    for i in np.arange(0,len(idx_a_4x2)):
        r=np.sqrt(radar.gate_x['data'][idx_a_4x2[i],:]**2+radar.gate_y['data'][idx_a_4x2[i],:]**2)
        idx_r = np.where((r>r0-75) & (r<r0+75))[1]
        if i==0:
            idx_r_4x2=[[idx_r-2],[idx_r-1],[idx_r],[idx_r+1]]
        else:
            idx_r_4x2=np.append(idx_r_4x2, [[idx_r-2],[idx_r-1],[idx_r],[idx_r+1]],axis=1)
    
    Azis=radar.azimuth['data'][idx_a_4x2]
    Ranges=radar.range['data'][idx_r_4x2]
    X=radar.gate_x['data'][idx_a_4x2, idx_r_4x2]
    Y=radar.gate_y['data'][idx_a_4x2, idx_r_4x2]
    Z=radar.gate_z['data'][idx_a_4x2, idx_r_4x2]+radar.altitude['data'].data[0]-base_alt
    #test=np.nanmean(np.nanmean(radar.fields['dBZ']['data'][idx_a_4x2, idx_r_4x2],0),0)
    return idx_a_4x2, idx_r_4x2, Azis, Ranges,  X, Y, Z,# test


#, idx_r_4x2, radar.gate_y['data'][idx_a_4x2,idx_r_4x2], radar.gate_z['data'][idx_a_4x2,idx_r_4x2],


Porton_Down_Azis_Idx,Porton_Down_Ranges_Idx, Porton_Down_Azis, Porton_Down_Ranges, Porton_Down_X, Porton_Down_Y, Porton_Down_Z = find_nearest_4x2( radar,radar_to_Porton_Down_Bearing,radar_to_Porton_Down_Distance,Porton_Down_Alt)
Bentley_Wood_Azis_Idx,Bentley_Wood_Ranges_Idx, Bentley_Wood_Azis, Bentley_Wood_Ranges, Bentley_Wood_X, Bentley_Wood_Y, Bentley_Wood_Z = find_nearest_4x2(radar,radar_to_Bentley_Wood_Bearing, radar_to_Bentley_Wood_Distance,Bentley_Wood_Alt)


radar.fields['dBZ']['data'][Porton_Down_Azis_Idx,Porton_Down_Ranges_Idx]=-10

radar.fields['dBZ']['data'][Bentley_Wood_Azis_Idx,Bentley_Wood_Ranges_Idx]=-10

#Write Out Pixel Metrics
df_Porton_Down = pd.DataFrame(columns=['Scan_Elevation_degrees'])
df_Porton_Down['Scan_Elevation_degrees']=radar.fixed_angle['data']

df_Porton_Down['Max_Range']=np.nanmax(np.nanmax(Porton_Down_Ranges,0),0)
df_Porton_Down['Mean_Range']=np.nanmean(np.nanmean(Porton_Down_Ranges,0),0)
df_Porton_Down['Min_Range']=np.nanmin(np.nanmin(Porton_Down_Ranges,0),0)

df_Porton_Down['Max_Azimuth']=np.nanmax(np.nanmax(Porton_Down_Azis,0),0)
df_Porton_Down['Mean_Azimuth']=np.nanmean(np.nanmean(Porton_Down_Azis,0),0)
df_Porton_Down['Min_Azimuth']=np.nanmin(np.nanmin(Porton_Down_Azis,0),0)

df_Porton_Down['Max_X_Distance_from_Radar']=np.nanmax(np.nanmax(Porton_Down_X,0),0)
df_Porton_Down['Mean_X_Distance_from_Radar']=np.nanmean(np.nanmean(Porton_Down_X,0),0)
df_Porton_Down['Min_X_Distance_from_Radar']=np.nanmin(np.nanmin(Porton_Down_X,0),0)

df_Porton_Down['Max_Y_Distance_from_Radar']=np.nanmax(np.nanmax(Porton_Down_Y,0),0)
df_Porton_Down['Mean_Y_Distance_from_Radar']=np.nanmean(np.nanmean(Porton_Down_Y,0),0)
df_Porton_Down['Min_Y_Distance_from_Radar']=np.nanmin(np.nanmin(Porton_Down_Y,0),0)

df_Porton_Down['Max_Altitude_Above_Ground']=np.nanmax(np.nanmax(Porton_Down_Z,0),0)
df_Porton_Down['Mean_Altitude_Above_Ground']=np.nanmean(np.nanmean(Porton_Down_Z,0),0)
df_Porton_Down['Min_Altitude_Above_Ground']=np.nanmin(np.nanmin(Porton_Down_Z,0),0)


df_Bentley_Wood = pd.DataFrame(columns=['Scan_Elevation_degrees'])
df_Bentley_Wood['Scan_Elevation_degrees']=radar.fixed_angle['data']

df_Bentley_Wood['Max_Range']=np.nanmax(np.nanmax(Bentley_Wood_Ranges,0),0)
df_Bentley_Wood['Mean_Range']=np.nanmean(np.nanmean(Bentley_Wood_Ranges,0),0)
df_Bentley_Wood['Min_Range']=np.nanmin(np.nanmin(Bentley_Wood_Ranges,0),0)

df_Bentley_Wood['Max_Azimuth']=np.nanmax(np.nanmax(Bentley_Wood_Azis,0),0)
df_Bentley_Wood['Mean_Azimuth']=np.nanmean(np.nanmean(Bentley_Wood_Azis,0),0)
df_Bentley_Wood['Min_Azimuth']=np.nanmin(np.nanmin(Bentley_Wood_Azis,0),0)

df_Bentley_Wood['Max_X_Distance_from_Radar']=np.nanmax(np.nanmax(Bentley_Wood_X,0),0)
df_Bentley_Wood['Mean_X_Distance_from_Radar']=np.nanmean(np.nanmean(Bentley_Wood_X,0),0)
df_Bentley_Wood['Min_X_Distance_from_Radar']=np.nanmin(np.nanmin(Bentley_Wood_X,0),0)

df_Bentley_Wood['Max_Y_Distance_from_Radar']=np.nanmax(np.nanmax(Bentley_Wood_Y,0),0)
df_Bentley_Wood['Mean_Y_Distance_from_Radar']=np.nanmean(np.nanmean(Bentley_Wood_Y,0),0)
df_Bentley_Wood['Min_Y_Distance_from_Radar']=np.nanmin(np.nanmin(Bentley_Wood_Y,0),0)

df_Bentley_Wood['Max_Altitude_Above_Ground']=np.nanmax(np.nanmax(Bentley_Wood_Z,0),0)
df_Bentley_Wood['Mean_Altitude_Above_Ground']=np.nanmean(np.nanmean(Bentley_Wood_Z,0),0)
df_Bentley_Wood['Min_Altitude_Above_Ground']=np.nanmin(np.nanmin(Bentley_Wood_Z,0),0)



try:
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Porton_Down_Closest_4x2_Metrics.xlsx')
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Bentley_Wood_Closest_4x2_Metrics.xlsx')

except:
    print('No File To Delete')
    
df_Porton_DownT=df_Porton_Down.T  
df_Bentley_WoodT=df_Bentley_Wood.T

df_Porton_DownT.to_excel("Porton_Down_Closest_4x2_Metrics.xlsx", sheet_name='Porton_Down_4x2_Metrics')
df_Bentley_WoodT.to_excel("Bentley_Wood_Closest_4x2_Metrics.xlsx", sheet_name='Bentley_Wood_4x2_Metrics')
# Out:
# No File To Delete

# %%
def find_nearest_6x3(radar,a0,r0, base_alt):
    idx_a = np.squeeze(np.where((radar.azimuth['data'][:]>a0-0.5) &  (radar.azimuth['data'][:]<a0+0.5))[0])
    idx_a_6x3=np.squeeze([idx_a-1,idx_a,idx_a+1])
    
    idx_r_6x3=[]
    for i in np.arange(0,len(idx_a_6x3)):
        r=np.sqrt(radar.gate_x['data'][idx_a_6x3[i],:]**2+radar.gate_y['data'][idx_a_6x3[i],:]**2)
        idx_r = np.where((r>r0-75) & (r<r0+75))[1]
        if i==0:
            idx_r_6x3=[[idx_r-3],[idx_r-2],[idx_r-1],[idx_r],[idx_r+1],[idx_r+2]]
        else:
            idx_r_6x3=np.append(idx_r_6x3, [[idx_r-3],[idx_r-2],[idx_r-1],[idx_r],[idx_r+1],[idx_r+2]],axis=1)
    
    Azis=radar.azimuth['data'][idx_a_6x3]
    Ranges=radar.range['data'][idx_r_6x3]
    X=radar.gate_x['data'][idx_a_6x3, idx_r_6x3]
    Y=radar.gate_y['data'][idx_a_6x3, idx_r_6x3]
    Z=radar.gate_z['data'][idx_a_6x3, idx_r_6x3]+radar.altitude['data'].data[0]-base_alt
    #test=np.nanmean(np.nanmean(radar.fields['dBZ']['data'][idx_a_6x3, idx_r_6x3],0),0)
    return idx_a_6x3, idx_r_6x3, Azis, Ranges,  X, Y, Z,# test


#, idx_r_6x3, radar.gate_y['data'][idx_a_6x3,idx_r_6x3], radar.gate_z['data'][idx_a_6x3,idx_r_6x3],


Porton_Down_Azis_Idx,Porton_Down_Ranges_Idx, Porton_Down_Azis, Porton_Down_Ranges, Porton_Down_X, Porton_Down_Y, Porton_Down_Z = find_nearest_6x3( radar,radar_to_Porton_Down_Bearing,radar_to_Porton_Down_Distance,Porton_Down_Alt)
Bentley_Wood_Azis_Idx,Bentley_Wood_Ranges_Idx, Bentley_Wood_Azis, Bentley_Wood_Ranges, Bentley_Wood_X, Bentley_Wood_Y, Bentley_Wood_Z = find_nearest_6x3(radar,radar_to_Bentley_Wood_Bearing, radar_to_Bentley_Wood_Distance,Bentley_Wood_Alt)


radar.fields['dBZ']['data'][Porton_Down_Azis_Idx,Porton_Down_Ranges_Idx]=0

radar.fields['dBZ']['data'][Bentley_Wood_Azis_Idx,Bentley_Wood_Ranges_Idx]=0

#Write Out Pixel Metrics
df_Porton_Down = pd.DataFrame(columns=['Scan_Elevation_degrees'])
df_Porton_Down['Scan_Elevation_degrees']=radar.fixed_angle['data']

df_Porton_Down['Max_Range']=np.nanmax(np.nanmax(Porton_Down_Ranges,0),0)
df_Porton_Down['Mean_Range']=np.nanmean(np.nanmean(Porton_Down_Ranges,0),0)
df_Porton_Down['Min_Range']=np.nanmin(np.nanmin(Porton_Down_Ranges,0),0)

df_Porton_Down['Max_Azimuth']=np.nanmax(np.nanmax(Porton_Down_Azis,0),0)
df_Porton_Down['Mean_Azimuth']=np.nanmean(np.nanmean(Porton_Down_Azis,0),0)
df_Porton_Down['Min_Azimuth']=np.nanmin(np.nanmin(Porton_Down_Azis,0),0)

df_Porton_Down['Max_X_Distance_from_Radar']=np.nanmax(np.nanmax(Porton_Down_X,0),0)
df_Porton_Down['Mean_X_Distance_from_Radar']=np.nanmean(np.nanmean(Porton_Down_X,0),0)
df_Porton_Down['Min_X_Distance_from_Radar']=np.nanmin(np.nanmin(Porton_Down_X,0),0)

df_Porton_Down['Max_Y_Distance_from_Radar']=np.nanmax(np.nanmax(Porton_Down_Y,0),0)
df_Porton_Down['Mean_Y_Distance_from_Radar']=np.nanmean(np.nanmean(Porton_Down_Y,0),0)
df_Porton_Down['Min_Y_Distance_from_Radar']=np.nanmin(np.nanmin(Porton_Down_Y,0),0)

df_Porton_Down['Max_Altitude_Above_Ground']=np.nanmax(np.nanmax(Porton_Down_Z,0),0)
df_Porton_Down['Mean_Altitude_Above_Ground']=np.nanmean(np.nanmean(Porton_Down_Z,0),0)
df_Porton_Down['Min_Altitude_Above_Ground']=np.nanmin(np.nanmin(Porton_Down_Z,0),0)


df_Bentley_Wood = pd.DataFrame(columns=['Scan_Elevation_degrees'])
df_Bentley_Wood['Scan_Elevation_degrees']=radar.fixed_angle['data']

df_Bentley_Wood['Max_Range']=np.nanmax(np.nanmax(Bentley_Wood_Ranges,0),0)
df_Bentley_Wood['Mean_Range']=np.nanmean(np.nanmean(Bentley_Wood_Ranges,0),0)
df_Bentley_Wood['Min_Range']=np.nanmin(np.nanmin(Bentley_Wood_Ranges,0),0)

df_Bentley_Wood['Max_Azimuth']=np.nanmax(np.nanmax(Bentley_Wood_Azis,0),0)
df_Bentley_Wood['Mean_Azimuth']=np.nanmean(np.nanmean(Bentley_Wood_Azis,0),0)
df_Bentley_Wood['Min_Azimuth']=np.nanmin(np.nanmin(Bentley_Wood_Azis,0),0)

df_Bentley_Wood['Max_X_Distance_from_Radar']=np.nanmax(np.nanmax(Bentley_Wood_X,0),0)
df_Bentley_Wood['Mean_X_Distance_from_Radar']=np.nanmean(np.nanmean(Bentley_Wood_X,0),0)
df_Bentley_Wood['Min_X_Distance_from_Radar']=np.nanmin(np.nanmin(Bentley_Wood_X,0),0)

df_Bentley_Wood['Max_Y_Distance_from_Radar']=np.nanmax(np.nanmax(Bentley_Wood_Y,0),0)
df_Bentley_Wood['Mean_Y_Distance_from_Radar']=np.nanmean(np.nanmean(Bentley_Wood_Y,0),0)
df_Bentley_Wood['Min_Y_Distance_from_Radar']=np.nanmin(np.nanmin(Bentley_Wood_Y,0),0)

df_Bentley_Wood['Max_Altitude_Above_Ground']=np.nanmax(np.nanmax(Bentley_Wood_Z,0),0)
df_Bentley_Wood['Mean_Altitude_Above_Ground']=np.nanmean(np.nanmean(Bentley_Wood_Z,0),0)
df_Bentley_Wood['Min_Altitude_Above_Ground']=np.nanmin(np.nanmin(Bentley_Wood_Z,0),0)



try:
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Porton_Down_Closest_6x3_Metrics.xlsx')
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Bentley_Wood_Closest_6x3_Metrics.xlsx')

except:
    print('No File To Delete')
    
df_Porton_DownT=df_Porton_Down.T  
df_Bentley_WoodT=df_Bentley_Wood.T

df_Porton_DownT.to_excel("Porton_Down_Closest_6x3_Metrics.xlsx", sheet_name='Porton_Down_6x3_Metrics')
df_Bentley_WoodT.to_excel("Bentley_Wood_Closest_6x3_Metrics.xlsx", sheet_name='Bentley_Wood_6x3_Metrics')
# Out:
# No File To Delete

# %%
def find_nearest_2x1(radar,a0,r0, base_alt):
    idx_a = np.squeeze(np.where((radar.azimuth['data'][:]>a0-0.5) &  (radar.azimuth['data'][:]<a0+0.5))[0])
    idx_a_2x1=np.squeeze([idx_a,])
    idx_r_2x1=[]
    for i in np.arange(0,len(idx_a_2x1)):
        r=np.sqrt(radar.gate_x['data'][idx_a_2x1[i],:]**2+radar.gate_y['data'][idx_a_2x1[i],:]**2)
        idx_r = np.where((r>r0-75) & (r<r0+75))[0].astype('int')

        if i==0:
            idx_r_2x1=[idx_r-1,idx_r]
        else:
            idx_r_2x1=np.append(idx_r_2x1, [idx_r-1,idx_r],axis=1)
    
    Azis=radar.azimuth['data'][idx_a_2x1]
    Ranges=radar.range['data'][idx_r_2x1]
    X=radar.gate_x['data'][idx_a_2x1, idx_r_2x1]
    Y=radar.gate_y['data'][idx_a_2x1, idx_r_2x1]
    Z=radar.gate_z['data'][idx_a_2x1, idx_r_2x1]+radar.altitude['data'].data[0]-base_alt
    #test=np.nanmean(np.nanmean(radar.fields['dBZ']['data'][idx_a_2x1, idx_r_2x1],0),0)
    return idx_a_2x1, idx_r_2x1, Azis, Ranges,  X, Y, Z,# test


#, idx_r_2x1, radar.gate_y['data'][idx_a_2x1,idx_r_2x1], radar.gate_z['data'][idx_a_2x1,idx_r_2x1],


Porton_Down_Azis_Idx,Porton_Down_Ranges_Idx, Porton_Down_Azis, Porton_Down_Ranges, Porton_Down_X, Porton_Down_Y, Porton_Down_Z = find_nearest_2x1( radar,radar_to_Porton_Down_Bearing,radar_to_Porton_Down_Distance,Porton_Down_Alt)
Bentley_Wood_Azis_Idx,Bentley_Wood_Ranges_Idx, Bentley_Wood_Azis, Bentley_Wood_Ranges, Bentley_Wood_X, Bentley_Wood_Y, Bentley_Wood_Z = find_nearest_2x1(radar,radar_to_Bentley_Wood_Bearing, radar_to_Bentley_Wood_Distance,Bentley_Wood_Alt)


radar.fields['dBZ']['data'][Porton_Down_Azis_Idx,Porton_Down_Ranges_Idx]=10

radar.fields['dBZ']['data'][Bentley_Wood_Azis_Idx,Bentley_Wood_Ranges_Idx]=10

#Write Out Pixel Metrics
df_Porton_Down = pd.DataFrame(columns=['Scan_Elevation_degrees'])
df_Porton_Down['Scan_Elevation_degrees']=radar.fixed_angle['data']

df_Porton_Down['Max_Range']=np.nanmax(Porton_Down_Ranges,0)
df_Porton_Down['Mean_Range']=np.nanmean(Porton_Down_Ranges,0)
df_Porton_Down['Min_Range']=np.nanmin(Porton_Down_Ranges,0)

df_Porton_Down['Max_Azimuth']=np.nanmax(Porton_Down_Azis,0)
df_Porton_Down['Mean_Azimuth']=np.nanmean(Porton_Down_Azis,0)
df_Porton_Down['Min_Azimuth']=np.nanmin(Porton_Down_Azis,0)

df_Porton_Down['Max_X_Distance_from_Radar']=np.nanmax(Porton_Down_X,0)
df_Porton_Down['Mean_X_Distance_from_Radar']=np.nanmean(Porton_Down_X,0)
df_Porton_Down['Min_X_Distance_from_Radar']=np.nanmin(Porton_Down_X,0)

df_Porton_Down['Max_Y_Distance_from_Radar']=np.nanmax(Porton_Down_Y,0)
df_Porton_Down['Mean_Y_Distance_from_Radar']=np.nanmean(Porton_Down_Y,0)
df_Porton_Down['Min_Y_Distance_from_Radar']=np.nanmin(Porton_Down_Y,0)

df_Porton_Down['Max_Altitude_Above_Ground']=np.nanmax(Porton_Down_Z,0)
df_Porton_Down['Mean_Altitude_Above_Ground']=np.nanmean(Porton_Down_Z,0)
df_Porton_Down['Min_Altitude_Above_Ground']=np.nanmin(Porton_Down_Z,0)


df_Bentley_Wood = pd.DataFrame(columns=['Scan_Elevation_degrees'])
df_Bentley_Wood['Scan_Elevation_degrees']=radar.fixed_angle['data']

df_Bentley_Wood['Max_Range']=np.nanmax(Bentley_Wood_Ranges,0)
df_Bentley_Wood['Mean_Range']=np.nanmean(Bentley_Wood_Ranges,0)
df_Bentley_Wood['Min_Range']=np.nanmin(Bentley_Wood_Ranges,0)

df_Bentley_Wood['Max_Azimuth']=np.nanmax(Bentley_Wood_Azis,0)
df_Bentley_Wood['Mean_Azimuth']=np.nanmean(Bentley_Wood_Azis,0)
df_Bentley_Wood['Min_Azimuth']=np.nanmin(Bentley_Wood_Azis,0)

df_Bentley_Wood['Max_X_Distance_from_Radar']=np.nanmax(Bentley_Wood_X,0)
df_Bentley_Wood['Mean_X_Distance_from_Radar']=np.nanmean(Bentley_Wood_X,0)
df_Bentley_Wood['Min_X_Distance_from_Radar']=np.nanmin(Bentley_Wood_X,0)

df_Bentley_Wood['Max_Y_Distance_from_Radar']=np.nanmax(Bentley_Wood_Y,0)
df_Bentley_Wood['Mean_Y_Distance_from_Radar']=np.nanmean(Bentley_Wood_Y,0)
df_Bentley_Wood['Min_Y_Distance_from_Radar']=np.nanmin(Bentley_Wood_Y,0)

df_Bentley_Wood['Max_Altitude_Above_Ground']=np.nanmax(Bentley_Wood_Z,0)
df_Bentley_Wood['Mean_Altitude_Above_Ground']=np.nanmean(Bentley_Wood_Z,0)
df_Bentley_Wood['Min_Altitude_Above_Ground']=np.nanmin(Bentley_Wood_Z,0)



try:
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Porton_Down_Closest_2x1_Metrics.xlsx')
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Bentley_Wood_Closest_2x1_Metrics.xlsx')

except:
    print('No File To Delete')
    
df_Porton_DownT=df_Porton_Down.T  
df_Bentley_WoodT=df_Bentley_Wood.T

df_Porton_DownT.to_excel("Porton_Down_Closest_2x1_Metrics.xlsx", sheet_name='Porton_Down_2x1_Metrics')
df_Bentley_WoodT.to_excel("Bentley_Wood_Closest_2x1_Metrics.xlsx", sheet_name='Bentley_Wood_2x1_Metrics')
# Out:
# No File To Delete

# %%
def find_nearest_1x1(radar,a0,r0, base_alt):
    idx_a_1x1=[]
    idx_r_1x1=[]
    idx_a = np.squeeze(np.where((radar.azimuth['data'][:]>a0-0.5) &  (radar.azimuth['data'][:]<a0+0.5))[0])
    idx_a_1x1=np.squeeze([idx_a,])
    

    r=np.sqrt(radar.gate_x['data'][idx_a_1x1[:],:]**2+radar.gate_y['data'][idx_a_1x1[:],:]**2)
    idx_r_1x1 = np.where((r>r0-75) & (r<r0+75))[1]

    Azis=radar.azimuth['data'][idx_a_1x1]
    Ranges=radar.range['data'][idx_r_1x1]
    X=radar.gate_x['data'][idx_a_1x1, idx_r_1x1]
    Y=radar.gate_y['data'][idx_a_1x1, idx_r_1x1]
    Z=radar.gate_z['data'][idx_a_1x1, idx_r_1x1]+radar.altitude['data'].data[0]-base_alt
    #test=radar.fields['dBZ']['data'][idx_a_1x1, idx_r_1x1]
    return idx_a_1x1, idx_r_1x1, Azis, Ranges,  X, Y, Z#, test


Porton_Down_Azis_Idx,Porton_Down_Ranges_Idx, Porton_Down_Azis, Porton_Down_Ranges, Porton_Down_X, Porton_Down_Y, Porton_Down_Z= find_nearest_1x1( radar,radar_to_Porton_Down_Bearing,radar_to_Porton_Down_Distance,Porton_Down_Alt)
Bentley_Wood_Azis_Idx,Bentley_Wood_Ranges_Idx, Bentley_Wood_Azis, Bentley_Wood_Ranges, Bentley_Wood_X, Bentley_Wood_Y, Bentley_Wood_Z = find_nearest_1x1(radar,radar_to_Bentley_Wood_Bearing, radar_to_Bentley_Wood_Distance,Bentley_Wood_Alt)

radar.fields['dBZ']['data'][Porton_Down_Azis_Idx,Porton_Down_Ranges_Idx]=20

radar.fields['dBZ']['data'][Bentley_Wood_Azis_Idx,Bentley_Wood_Ranges_Idx]=20



#Write Out Pixel Metrics
df_Porton_Down = pd.DataFrame(columns=['Scan_Elevation_degrees'])
df_Porton_Down['Scan_Elevation_degrees']=radar.fixed_angle['data']

df_Porton_Down['Max_Range']=Porton_Down_Ranges
df_Porton_Down['Mean_Range']=Porton_Down_Ranges
df_Porton_Down['Min_Range']=Porton_Down_Ranges

df_Porton_Down['Max_Azimuth']=Porton_Down_Azis
df_Porton_Down['Mean_Azimuth']=Porton_Down_Azis
df_Porton_Down['Min_Azimuth']=Porton_Down_Azis

df_Porton_Down['Max_X_Distance_from_Radar']=Porton_Down_X
df_Porton_Down['Mean_X_Distance_from_Radar']=Porton_Down_X
df_Porton_Down['Min_X_Distance_from_Radar']=Porton_Down_X

df_Porton_Down['Max_Y_Distance_from_Radar']=Porton_Down_Y
df_Porton_Down['Mean_Y_Distance_from_Radar']=Porton_Down_Y
df_Porton_Down['Min_Y_Distance_from_Radar']=Porton_Down_Y

df_Porton_Down['Max_Altitude_Above_Ground']=Porton_Down_Z
df_Porton_Down['Mean_Altitude_Above_Ground']=Porton_Down_Z
df_Porton_Down['Min_Altitude_Above_Ground']=Porton_Down_Z


df_Bentley_Wood = pd.DataFrame(columns=['Scan_Elevation_degrees'])
df_Bentley_Wood['Scan_Elevation_degrees']=radar.fixed_angle['data']

df_Bentley_Wood['Max_Range']=Bentley_Wood_Ranges
df_Bentley_Wood['Mean_Range']=Bentley_Wood_Ranges
df_Bentley_Wood['Min_Range']=Bentley_Wood_Ranges

df_Bentley_Wood['Max_Azimuth']=Bentley_Wood_Azis
df_Bentley_Wood['Mean_Azimuth']=Bentley_Wood_Azis
df_Bentley_Wood['Min_Azimuth']=Bentley_Wood_Azis

df_Bentley_Wood['Max_X_Distance_from_Radar']=Bentley_Wood_X
df_Bentley_Wood['Mean_X_Distance_from_Radar']=Bentley_Wood_X
df_Bentley_Wood['Min_X_Distance_from_Radar']=Bentley_Wood_X

df_Bentley_Wood['Max_Y_Distance_from_Radar']=Bentley_Wood_Y
df_Bentley_Wood['Mean_Y_Distance_from_Radar']=Bentley_Wood_Y
df_Bentley_Wood['Min_Y_Distance_from_Radar']=Bentley_Wood_Y

df_Bentley_Wood['Max_Altitude_Above_Ground']=Bentley_Wood_Z
df_Bentley_Wood['Mean_Altitude_Above_Ground']=Bentley_Wood_Z
df_Bentley_Wood['Min_Altitude_Above_Ground']=Bentley_Wood_Z



try:
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Porton_Down_Closest_1x1_Metrics.xlsx')
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Bentley_Wood_Closest_1x1_Metrics.xlsx')

except:
    print('No File To Delete')
    
df_Porton_DownT=df_Porton_Down.T  
df_Bentley_WoodT=df_Bentley_Wood.T

df_Porton_DownT.to_excel("Porton_Down_Closest_1x1_Metrics.xlsx", sheet_name='Porton_Down_1x1_Metrics')
df_Bentley_WoodT.to_excel("Bentley_Wood_Closest_1x1_Metrics.xlsx", sheet_name='Bentley_Wood_1x1_Metrics')
# Out:
# No File To Delete

# %%
display = pyart.graph.RadarMapDisplay(radar)
fig = plt.figure(figsize = (20,16))
fig.patch.set_facecolor('white')

# Setting projection and ploting the second tilt
projection = ccrs.LambertConformal(central_latitude=radar.latitude['data'][0],
                                   central_longitude=radar.longitude['data'][0])




display.plot_ppi_map('dBZ',1 , vmin=-20, vmax=20, resolution='10m', projection=projection,
                     min_lon=radar.longitude['data'][0]-0.4, max_lon=radar.longitude['data'][0]+0.4, 
                     min_lat=radar.latitude['data'][0]-0.25, max_lat=radar.latitude['data'][0]+0.25,
                     fig=fig, lat_0=radar.latitude['data'][0],
                     lon_0=radar.longitude['data'][0],cmap='pyart_HomeyerRainbow')

# Plot range rings at 10, 20, 30, 40km
display.plot_range_ring(5., line_style='k-')
display.plot_range_ring(10., line_style='k--')
display.plot_range_ring(15., line_style='k-')
display.plot_range_ring(20., line_style='k--')
display.plot_range_ring(25., line_style='k-')

# Plot cross hairs

# Indicate the radar location with a point
display.plot_point(radar.longitude['data'][0], radar.latitude['data'][0],symbol='mo',markersize=10)

display.plot_point(Porton_Down_Long, Porton_Down_Lat,symbol='m*',markersize=2)

display.plot_point(Bentley_Wood_Long, Bentley_Wood_Lat,symbol='mh',markersize=2)
# Out:
# /Users/rrniii/anaconda3/envs/biodar/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:782: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_xticks(xticks, minor)
# /Users/rrniii/anaconda3/envs/biodar/lib/python3.7/site-packages/cartopy/mpl/geoaxes.py:829: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   return super(GeoAxes, self).set_yticks(yticks, minor)

# %%
#Extract data and put in dataframe
Porton_Down={}
Bentley_Wood={}
Porton_Down_2x1={}
Bentley_Wood_2x1={}
Porton_Down_4x2={}
Bentley_Wood_4x2={}
Porton_Down_6x3={}
Bentley_Wood_6x3={}
Porton_Down_7x3={}
Bentley_Wood_7x3={}


fields=['RhoHV', 'SNRv', 'ZDR', 'dBZ', 'uKDPu', 'PhiDP', 'dBuZ', 'uPhiDP', 'KDP', 'dBZv', 'dBuZv', 'SNRvu', 'RhoHVu', 'SNRu', 'ZDRu', 'u_wind_component', 'temperature', 'uPhiDPu', 'rh', 'v_wind_component', 'SNR', 'uKDP']

for v in fields:
    Porton_Down["{0}".format(v)] = np.array([])
    Bentley_Wood["{0}".format(v)] = np.array([])
    Porton_Down_7x3["{0}".format(v)] = np.array([])
    Bentley_Wood_7x3["{0}".format(v)] = np.array([])
    
files=all_files(data_dir,'201707')
print(len(files))
print(files[0])
print(files[-1])    
for idx, f in enumerate(files[:]):
    print(f)
    radar=pyart.io.read(f)
    
    Porton_Down_Azis_Idx_1x1,Porton_Down_Ranges_Idx_1x1, Porton_Down_Azis_1x1, Porton_Down_Ranges_1x1, Porton_Down_X_1x1, Porton_Down_Y_1x1, Porton_Down_Z_1x1 =find_nearest_1x1( radar,radar_to_Porton_Down_Bearing,radar_to_Porton_Down_Distance,Porton_Down_Alt)
    Bentley_Wood_Azis_Idx_1x1,Bentley_Wood_Ranges_Idx_1x1, Bentley_Wood_Azis_1x1, Bentley_Wood_Ranges_1x1, Bentley_Wood_X_1x1, Bentley_Wood_Y_1x1, Bentley_Wood_Z_1x1 =find_nearest_1x1(radar,radar_to_Bentley_Wood_Bearing, radar_to_Bentley_Wood_Distance,Bentley_Wood_Alt)
    
    Porton_Down_Azis_Idx_2x1,Porton_Down_Ranges_Idx_2x1, Porton_Down_Azis_2x1, Porton_Down_Ranges_2x1, Porton_Down_X_2x1, Porton_Down_Y_2x1, Porton_Down_Z_2x1 =find_nearest_2x1( radar,radar_to_Porton_Down_Bearing,radar_to_Porton_Down_Distance,Porton_Down_Alt)
    Bentley_Wood_Azis_Idx_2x1,Bentley_Wood_Ranges_Idx_2x1, Bentley_Wood_Azis_2x1, Bentley_Wood_Ranges_2x1, Bentley_Wood_X_2x1, Bentley_Wood_Y_2x1, Bentley_Wood_Z_2x1 =find_nearest_2x1(radar,radar_to_Bentley_Wood_Bearing, radar_to_Bentley_Wood_Distance,Bentley_Wood_Alt)
    
    Porton_Down_Azis_Idx_4x2,Porton_Down_Ranges_Idx_4x2, Porton_Down_Azis_4x2, Porton_Down_Ranges_4x2, Porton_Down_X_4x2, Porton_Down_Y_4x2, Porton_Down_Z_4x2 =find_nearest_4x2( radar,radar_to_Porton_Down_Bearing,radar_to_Porton_Down_Distance,Porton_Down_Alt)
    Bentley_Wood_Azis_Idx_4x2,Bentley_Wood_Ranges_Idx_4x2, Bentley_Wood_Azis_4x2, Bentley_Wood_Ranges_4x2, Bentley_Wood_X_4x2, Bentley_Wood_Y_4x2, Bentley_Wood_Z_4x2 =find_nearest_4x2(radar,radar_to_Bentley_Wood_Bearing, radar_to_Bentley_Wood_Distance,Bentley_Wood_Alt)
    
    Porton_Down_Azis_Idx_6x3,Porton_Down_Ranges_Idx_6x3, Porton_Down_Azis_6x3, Porton_Down_Ranges_6x3, Porton_Down_X_6x3, Porton_Down_Y_6x3, Porton_Down_Z_6x3 =find_nearest_6x3( radar,radar_to_Porton_Down_Bearing,radar_to_Porton_Down_Distance,Porton_Down_Alt)
    Bentley_Wood_Azis_Idx_6x3,Bentley_Wood_Ranges_Idx_6x3, Bentley_Wood_Azis_6x3, Bentley_Wood_Ranges_6x3, Bentley_Wood_X_6x3, Bentley_Wood_Y_6x3, Bentley_Wood_Z_6x3 =find_nearest_6x3(radar,radar_to_Bentley_Wood_Bearing, radar_to_Bentley_Wood_Distance,Bentley_Wood_Alt)
    
    Porton_Down_Azis_Idx_7x3,Porton_Down_Ranges_Idx_7x3, Porton_Down_Azis_7x3, Porton_Down_Ranges_7x3, Porton_Down_X_7x3, Porton_Down_Y_7x3, Porton_Down_Z_7x3  =find_nearest_7x3( radar,radar_to_Porton_Down_Bearing,radar_to_Porton_Down_Distance,Porton_Down_Alt)
    Bentley_Wood_Azis_Idx_7x3,Bentley_Wood_Ranges_Idx_7x3, Bentley_Wood_Azis_7x3, Bentley_Wood_Ranges_7x3, Bentley_Wood_X_7x3, Bentley_Wood_Y_7x3, Bentley_Wood_Z_7x3 =find_nearest_7x3(radar,radar_to_Bentley_Wood_Bearing, radar_to_Bentley_Wood_Distance,Bentley_Wood_Alt)

    
    for k in Porton_Down.keys():
        Porton_Down_k_2x1=[np.append(pyart.util.datetime_from_radar(radar),np.nanmean(radar.fields[k]['data'][Porton_Down_Azis_Idx_2x1,Porton_Down_Ranges_Idx_2x1].data,0))]
        Bentley_Wood_k_2x1=[np.append(pyart.util.datetime_from_radar(radar),np.nanmean(radar.fields[k]['data'][Bentley_Wood_Azis_Idx_2x1,Bentley_Wood_Ranges_Idx_2x1].data,0))]
        
        Porton_Down_k_4x2=[np.append(pyart.util.datetime_from_radar(radar),np.nanmean(np.nanmean(radar.fields[k]['data'][Porton_Down_Azis_Idx_4x2,Porton_Down_Ranges_Idx_4x2].data,0),0))]
        Bentley_Wood_k_4x2=[np.append(pyart.util.datetime_from_radar(radar),np.nanmean(np.nanmean(radar.fields[k]['data'][Bentley_Wood_Azis_Idx_4x2,Bentley_Wood_Ranges_Idx_4x2].data,0),0))]
        
        Porton_Down_k_6x3=[np.append(pyart.util.datetime_from_radar(radar),np.nanmean(np.nanmean(radar.fields[k]['data'][Porton_Down_Azis_Idx_6x3,Porton_Down_Ranges_Idx_6x3].data,0),0))]
        Bentley_Wood_k_6x3=[np.append(pyart.util.datetime_from_radar(radar),np.nanmean(np.nanmean(radar.fields[k]['data'][Bentley_Wood_Azis_Idx_6x3,Bentley_Wood_Ranges_Idx_6x3].data,0),0))]
        
        Porton_Down_k_7x3=[np.append(pyart.util.datetime_from_radar(radar),np.nanmean(np.nanmean(radar.fields[k]['data'][Porton_Down_Azis_Idx_7x3,Porton_Down_Ranges_Idx_7x3].data,0),0))]
        Bentley_Wood_k_7x3=[np.append(pyart.util.datetime_from_radar(radar),np.nanmean(np.nanmean(radar.fields[k]['data'][Bentley_Wood_Azis_Idx_7x3,Bentley_Wood_Ranges_Idx_7x3].data,0),0))]

        if idx==0:
            Porton_Down[k]=[np.append(pyart.util.datetime_from_radar(radar),np.squeeze([radar.fields[k]['data'][Porton_Down_Azis_Idx_1x1,Porton_Down_Ranges_Idx_1x1].data]))]
            Bentley_Wood[k]=[np.append(pyart.util.datetime_from_radar(radar),np.squeeze([radar.fields[k]['data'][Bentley_Wood_Azis_Idx_1x1,Bentley_Wood_Ranges_Idx_1x1].data]))]
            
            Porton_Down_2x1[k]=Porton_Down_k_2x1
            Bentley_Wood_2x1[k]=Bentley_Wood_k_2x1
            
            Porton_Down_4x2[k]=Porton_Down_k_4x2
            Bentley_Wood_4x2[k]=Bentley_Wood_k_4x2
            
            Porton_Down_6x3[k]=Porton_Down_k_6x3
            Bentley_Wood_6x3[k]=Bentley_Wood_k_6x3
            
            Porton_Down_7x3[k]=Porton_Down_k_7x3
            Bentley_Wood_7x3[k]=Bentley_Wood_k_7x3
        else:
            Porton_Down[k]=np.append(Porton_Down[k],[np.append(pyart.util.datetime_from_radar(radar),np.squeeze([radar.fields[k]['data'][Porton_Down_Azis_Idx[:],Porton_Down_Ranges_Idx].data]))],0)
            Bentley_Wood[k]=np.append(Bentley_Wood[k],[np.append(pyart.util.datetime_from_radar(radar),np.squeeze([radar.fields[k]['data'][Bentley_Wood_Azis_Idx[:],Bentley_Wood_Ranges_Idx].data]))],0)
            
            Porton_Down_2x1[k]=np.append(Porton_Down_2x1[k],Porton_Down_k_2x1,0)
            Bentley_Wood_2x1[k]=np.append(Bentley_Wood_2x1[k],Bentley_Wood_k_2x1,0)
            
            Porton_Down_4x2[k]=np.append(Porton_Down_4x2[k],Porton_Down_k_4x2,0)
            Bentley_Wood_4x2[k]=np.append(Bentley_Wood_4x2[k],Bentley_Wood_k_4x2,0)
            
            Porton_Down_6x3[k]=np.append(Porton_Down_6x3[k],Porton_Down_k_6x3,0)
            Bentley_Wood_6x3[k]=np.append(Bentley_Wood_6x3[k],Bentley_Wood_k_6x3,0)
            
            Porton_Down_7x3[k]=np.append(Porton_Down_7x3[k],Porton_Down_k_7x3,0)
            Bentley_Wood_7x3[k]=np.append(Bentley_Wood_7x3[k],Bentley_Wood_k_7x3,0)
            
    del radar

#Write dictionary to dataframes and output into excel
radar=pyart.io.read(f)

Porton_Down_Vars=[]
Bentley_Wood_Vars=[]

Porton_Down_Vars_2x1=[]
Bentley_Wood_Vars_2x1=[]

Porton_Down_Vars_4x2=[]
Bentley_Wood_Vars_4x2=[]

Porton_Down_Vars_6x3=[]
Bentley_Wood_Vars_6x3=[]

Porton_Down_Vars_7x3=[]
Bentley_Wood_Vars_7x3=[]
try:
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Porton_Down_Closest_1x1.xlsx')
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Bentley_Wood_Closest_1x1.xlsx')

    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Porton_Down_Closest_2x1.xlsx')
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Bentley_Wood_Closest_2x1.xlsx')
    
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Porton_Down_Closest_4x2.xlsx')
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Bentley_Wood_Closest_4x2.xlsx')
    
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Porton_Down_Closest_6x3.xlsx')
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Bentley_Wood_Closest_6x3.xlsx')
    
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Porton_Down_Closest_7x3.xlsx')
    os.remove('/Users/rrniii/Google_Drive/code/PycharmProjects/biodar/notebooks/July/Bentley_Wood_Closest_7x3.xlsx')
except:
    print('No File')

for kidx, k in enumerate(Porton_Down.keys()):
  
    Porton_Down_Vars=np.append(Porton_Down_Vars,'Porton_Down_'+str(k))
    Bentley_Wood_Vars=np.append(Bentley_Wood_Vars,'Bentley_Wood_'+str(k))
    
    Porton_Down_Vars_2x1=np.append(Porton_Down_Vars_2x1,'Porton_Down_2x1_'+str(k))
    Bentley_Wood_Vars_2x1=np.append(Bentley_Wood_Vars_2x1,'Bentley_Wood_2x1_'+str(k))
    
    Porton_Down_Vars_4x2=np.append(Porton_Down_Vars_4x2,'Porton_Down_4x2_'+str(k))
    Bentley_Wood_Vars_4x2=np.append(Bentley_Wood_Vars_4x2,'Bentley_Wood_4x2_'+str(k))
    
    Porton_Down_Vars_7x3=np.append(Porton_Down_Vars_6x3,'Porton_Down_6x3_'+str(k))
    Bentley_Wood_Vars_7x3=np.append(Bentley_Wood_Vars_6x3,'Bentley_Wood_6x3_'+str(k))
    
    Porton_Down_Vars_7x3=np.append(Porton_Down_Vars_7x3,'Porton_Down_7x3_'+str(k))
    Bentley_Wood_Vars_7x3=np.append(Bentley_Wood_Vars_7x3,'Bentley_Wood_7x3_'+str(k))

    globals()['Porton_Down_'+str(k)]=pd.DataFrame(Porton_Down[k],columns=[np.append('Date Time', radar.fixed_angle['data'].data.astype('str'))])
    globals()['Bentley_Wood_'+str(k)]=pd.DataFrame(Bentley_Wood[k],columns=[np.append('Date Time', radar.fixed_angle['data'].data.astype('str'))])

    globals()['Porton_Down_2x1_'+str(k)]=pd.DataFrame(Porton_Down_2x1[k],columns=[np.append('Date Time', radar.fixed_angle['data'].data.astype('str'))])
    globals()['Bentley_Wood_2x1_'+str(k)]=pd.DataFrame(Bentley_Wood_2x1[k],columns=[np.append('Date Time', radar.fixed_angle['data'].data.astype('str'))])
    
    globals()['Porton_Down_4x2_'+str(k)]=pd.DataFrame(Porton_Down_4x2[k],columns=[np.append('Date Time', radar.fixed_angle['data'].data.astype('str'))])
    globals()['Bentley_Wood_4x2_'+str(k)]=pd.DataFrame(Bentley_Wood_4x2[k],columns=[np.append('Date Time', radar.fixed_angle['data'].data.astype('str'))])
    
    globals()['Porton_Down_6x3_'+str(k)]=pd.DataFrame(Porton_Down_6x3[k],columns=[np.append('Date Time', radar.fixed_angle['data'].data.astype('str'))])
    globals()['Bentley_Wood_6x3_'+str(k)]=pd.DataFrame(Bentley_Wood_6x3[k],columns=[np.append('Date Time', radar.fixed_angle['data'].data.astype('str'))])
    
    globals()['Porton_Down_7x3_'+str(k)]=pd.DataFrame(Porton_Down_7x3[k],columns=[np.append('Date Time', radar.fixed_angle['data'].data.astype('str'))])
    globals()['Bentley_Wood_7x3_'+str(k)]=pd.DataFrame(Bentley_Wood_7x3[k],columns=[np.append('Date Time', radar.fixed_angle['data'].data.astype('str'))])

    if kidx==0:
        globals()['Porton_Down_'+str(k)].to_excel("Porton_Down_Closest_1x1.xlsx", sheet_name='Porton_Down_1x1_'+str(k))
        globals()['Bentley_Wood_'+str(k)].to_excel("Bentley_Wood_Closest_1x1.xlsx", sheet_name='Bentley_Wood_1x1_'+str(k)) 
        
        globals()['Porton_Down_2x1_'+str(k)].to_excel("Porton_Down_Closest_2x1.xlsx", sheet_name='Porton_Down_2x1_'+str(k))
        globals()['Bentley_Wood_2x1_'+str(k)].to_excel("Bentley_Wood_Closest_2x1.xlsx", sheet_name='Bentley_Wood_2x1_'+str(k)) 

        globals()['Porton_Down_4x2_'+str(k)].to_excel("Porton_Down_Closest_4x2.xlsx", sheet_name='Porton_Down_4x2_'+str(k))
        globals()['Bentley_Wood_4x2_'+str(k)].to_excel("Bentley_Wood_Closest_4x2.xlsx", sheet_name='Bentley_Wood_4x2_'+str(k)) 

        globals()['Porton_Down_6x3_'+str(k)].to_excel("Porton_Down_Closest_6x3.xlsx", sheet_name='Porton_Down_6x3_'+str(k))
        globals()['Bentley_Wood_6x3_'+str(k)].to_excel("Bentley_Wood_Closest_6x3.xlsx", sheet_name='Bentley_Wood_6x3_'+str(k)) 

        globals()['Porton_Down_7x3_'+str(k)].to_excel("Porton_Down_Closest_7x3.xlsx", sheet_name='Porton_Down_7x3_'+str(k))
        globals()['Bentley_Wood_7x3_'+str(k)].to_excel("Bentley_Wood_Closest_7x3.xlsx", sheet_name='Bentley_Wood_7x3_'+str(k)) 

    else:
        with pd.ExcelWriter('Porton_Down_Closest_1x1.xlsx', mode='a') as writer:  
            globals()['Porton_Down_'+str(k)].to_excel(writer, sheet_name='Porton_Down_1x1_'+str(k)) 
        with pd.ExcelWriter('Bentley_Wood_Closest_1x1.xlsx', mode='a') as writer:  
            globals()['Bentley_Wood_'+str(k)].to_excel(writer, sheet_name='Bentley_Wood_1x1_'+str(k)) 
            
        with pd.ExcelWriter('Porton_Down_Closest_2x1.xlsx', mode='a') as writer:  
            globals()['Porton_Down_2x1_'+str(k)].to_excel(writer, sheet_name='Porton_Down_2x1_'+str(k)) 
        with pd.ExcelWriter('Bentley_Wood_Closest_2x1.xlsx', mode='a') as writer:  
            globals()['Bentley_Wood_2x1_'+str(k)].to_excel(writer, sheet_name='Bentley_Wood_2x1_'+str(k)) 
        
        with pd.ExcelWriter('Porton_Down_Closest_4x2.xlsx', mode='a') as writer:  
            globals()['Porton_Down_4x2_'+str(k)].to_excel(writer, sheet_name='Porton_Down_4x2_'+str(k)) 
        with pd.ExcelWriter('Bentley_Wood_Closest_4x2.xlsx', mode='a') as writer:  
            globals()['Bentley_Wood_4x2_'+str(k)].to_excel(writer, sheet_name='Bentley_Wood_4x2_'+str(k)) 
        
        with pd.ExcelWriter('Porton_Down_Closest_6x3.xlsx', mode='a') as writer:  
            globals()['Porton_Down_6x3_'+str(k)].to_excel(writer, sheet_name='Porton_Down_6x3_'+str(k)) 
        with pd.ExcelWriter('Bentley_Wood_Closest_6x3.xlsx', mode='a') as writer:  
            globals()['Bentley_Wood_6x3_'+str(k)].to_excel(writer, sheet_name='Bentley_Wood_6x3_'+str(k)) 
            
        with pd.ExcelWriter('Porton_Down_Closest_7x3.xlsx', mode='a') as writer:  
            globals()['Porton_Down_7x3_'+str(k)].to_excel(writer, sheet_name='Porton_Down_7x3_'+str(k)) 
        with pd.ExcelWriter('Bentley_Wood_Closest_7x3.xlsx', mode='a') as writer:  
            globals()['Bentley_Wood_7x3_'+str(k)].to_excel(writer, sheet_name='Bentley_Wood_7x3_'+str(k))
# Out:
# /Volumes/BioTxfer/calib_v2_2_sur/*/201707*
# 1806
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-000338_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-142714_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-000338_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-001020_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-001701_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-002342_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-003041_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-003720_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-004401_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-005042_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-005723_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-010405_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-011047_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-011728_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-012410_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-013107_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-013747_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-014428_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-015109_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-015749_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-020430_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-021112_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-021753_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-022434_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-023132_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-023812_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-024454_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-025135_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-025816_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-030458_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-031139_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-031820_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-032501_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-033159_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-033838_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-034519_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-035201_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-035843_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-040524_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-041206_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-041849_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-042530_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-043228_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-043907_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-044548_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-045229_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-045910_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-050552_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-051233_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-051915_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-052556_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-053254_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-053934_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-054616_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-055257_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-055940_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-060621_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-061301_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-061942_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-062624_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-063322_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-064002_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-064642_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-065324_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-070005_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-070646_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-071328_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-072009_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-072651_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-073349_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-074029_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-074709_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-075351_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-080033_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-080714_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-081356_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-082037_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-082718_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-083416_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-084056_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-084737_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-085419_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-090100_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-090741_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-091422_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-092104_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-092744_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-093442_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-094122_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-094804_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-095445_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-100126_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-100808_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-101449_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-102129_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-102810_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-103508_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-104148_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-104829_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-105510_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-110150_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-110831_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-111513_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-112154_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-112836_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-113533_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-114213_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-114854_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-115535_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-120216_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-120857_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-121539_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-122220_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-122901_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-123600_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-124239_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-124919_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-125601_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-130242_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-130923_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-131604_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-132246_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-132927_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-133625_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-134304_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-134945_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-135626_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-140307_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-140948_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-141629_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-142310_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-142951_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-143648_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-144327_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-145008_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-145649_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-150330_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-151012_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-151653_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-152333_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-153032_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-153711_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-154352_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-155034_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-155715_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-160356_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-161036_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-161718_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-162359_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-163056_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-163735_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-164417_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-165058_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-165739_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-170421_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-171102_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-171743_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-172425_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-173123_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-173802_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-174443_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-175124_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-175805_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-180446_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-181128_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-181809_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-182450_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-183148_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-183827_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-184508_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-185150_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-185832_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-190513_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-191155_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-191837_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-192519_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-193217_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-193856_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-194538_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-195219_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-195901_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-200542_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-201222_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-201903_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-202543_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-203239_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-203918_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-204600_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-205241_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-205921_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-210602_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-211242_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-211923_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-212604_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-213302_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-213941_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-214622_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-215303_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-215945_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-220626_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-221306_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-221948_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-222629_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-223327_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-224007_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-224648_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-225329_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-230011_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-230652_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-231334_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-232015_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-232656_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-233354_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-234033_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-234714_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170704/ncas-mobile-x-band-radar-1_chilbolton_20170704-235355_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-000037_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-000718_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-001359_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-002041_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-002720_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-003410_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-004043_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-004722_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-005356_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-010034_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-010708_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-011342_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-012016_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-012654_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-013345_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-014017_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-014651_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-015324_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-015958_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-020632_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-021306_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-021940_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-022614_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-023304_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-023936_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-024611_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-025244_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-025918_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-030552_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-031225_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-031904_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-032538_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-033233_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-033905_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-034543_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-035217_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-035850_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-040529_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-041207_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-041841_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-042514_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-043205_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-043837_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-044511_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-045145_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-045819_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-050457_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-051131_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-051805_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-052443_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-053135_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-053807_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-054445_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-055120_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-055753_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-060431_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-061105_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-061739_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-062413_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-063104_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-063743_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-064422_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-065105_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-065749_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-070432_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-071116_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-071759_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-072440_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-073136_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-073813_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-074447_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-075120_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-075753_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-080426_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-081059_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-081733_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-082407_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-083057_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-083730_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-084403_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-085041_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-085715_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-090348_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-091021_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-091655_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-092329_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-093007_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-093658_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-094329_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-095003_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-095636_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-100310_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-100949_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-101622_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-102256_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-102928_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-103618_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-104251_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-104924_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-105602_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-110236_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-110910_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-111545_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-154657_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-155339_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-160039_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-160719_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-161400_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-162041_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-162722_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-163403_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-164043_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-164724_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-165405_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-170102_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-170741_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-171422_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-172103_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-172744_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-173424_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-174106_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-174747_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-175428_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-180127_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-180806_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-181446_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-182127_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-182807_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-183447_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-184128_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-184809_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-185450_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-190147_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-190826_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-191506_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-192148_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-192830_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-193512_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-194152_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-194833_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-195515_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-200212_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-200852_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-201534_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-202215_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-202856_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-203536_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-204217_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-204858_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-205539_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-210237_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-210916_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-211557_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-212239_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-212920_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-213601_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-214242_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-214923_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-215605_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-220303_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-220942_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-221623_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-222305_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-222947_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-223628_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-224309_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-224950_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-225631_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-230328_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-231007_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-231648_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-232330_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-233010_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-233650_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-234331_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-235012_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170705/ncas-mobile-x-band-radar-1_chilbolton_20170705-235653_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-000352_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-001031_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-001712_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-002352_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-003032_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-003711_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-004351_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-005030_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-005709_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-010406_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-011046_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-011728_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-012408_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-013049_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-013731_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-014413_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-015054_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-015735_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-020433_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-021112_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-021754_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-022435_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-023115_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-023755_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-024436_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-025117_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-025758_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-030456_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-031136_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-031817_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-032459_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-033140_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-033820_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-034501_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-035142_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-035823_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-040521_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-041200_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-041841_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-042522_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-043204_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-043846_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-044527_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-045208_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-045850_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-050549_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-051227_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-051909_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-052550_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-053231_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-053912_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-054554_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-055235_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-055918_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-060616_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-061255_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-061936_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-062616_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170706/ncas-mobile-x-band-radar-1_chilbolton_20170706-063257_SUR_v1.nc
# ...
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-215930_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-220629_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-221309_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-221950_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-222632_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-223314_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-223955_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-224637_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-225318_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-230000_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-230658_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-231338_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-232020_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-232701_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-233343_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-234025_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-234708_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170711/ncas-mobile-x-band-radar-1_chilbolton_20170711-235351_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-000049_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-000729_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-001412_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-002054_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-002737_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-003419_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-004102_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-004745_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-005427_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-010127_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-010809_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-011451_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-012134_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-012816_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-013459_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-014141_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-014823_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-015506_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-020205_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-020846_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-021528_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-022210_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-022853_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-023535_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-024217_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-024859_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-025541_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-030239_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-030920_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-031602_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-032245_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-032927_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-033609_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-034251_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-034932_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-035614_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-040312_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-040952_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-041634_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-042315_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-042957_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-043639_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-044319_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-045001_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-045642_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-050339_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-051019_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-051659_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-052341_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-053022_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-053703_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-054345_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-055027_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-055707_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-060406_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-061046_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-061728_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-062409_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-063051_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-063732_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-064412_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-065054_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-065735_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-070433_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-071112_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-071753_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-072434_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-073115_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-073756_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-074437_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-075118_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-075759_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-080456_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-081136_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-081817_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-082458_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-083139_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-083821_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-084502_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-085143_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-085823_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-090521_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-091201_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-091842_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-092522_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-093203_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-093845_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-094526_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-095207_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-095848_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-100546_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-101226_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-101907_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-102548_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-103229_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-103910_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-104552_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-105232_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-105914_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-110612_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-111251_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-111932_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-112612_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-113253_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-113933_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-114613_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-115254_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-115935_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-120633_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-121312_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-121952_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-122633_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-123313_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-123954_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-124635_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-125315_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-125957_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-130655_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-131334_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-132014_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-132655_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-133335_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-134016_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-134656_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-135336_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-140032_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-140712_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-141353_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-142034_SUR_v1.nc
# /Volumes/BioTxfer/calib_v2_2_sur/20170712/ncas-mobile-x-band-radar-1_chilbolton_20170712-142714_SUR_v1.nc
# No File
# /Users/rrniii/anaconda3/envs/biodar/lib/python3.7/site-packages/openpyxl/workbook/child.py:99: UserWarning: Title is more than 31 characters. Some applications may not be able to read the file
#   warnings.warn("Title is more than 31 characters. Some applications may not be able to read the file")
